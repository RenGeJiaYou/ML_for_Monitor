# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. 读取数据

# %%
# 读取csv 文件
df = pd.read_csv('../data/ip_student.csv')

# 查看数据
df.describe()
# Out:
#        uniqueClientIdsCount  uniqueTrainingPersonIdsCount
# count           1217.000000                   1217.000000
# mean               1.692687                      7.447001
# std                0.682888                     95.718031
# min                1.000000                      2.000000
# 25%                1.000000                      2.000000
# 50%                2.000000                      2.000000
# 75%                2.000000                      3.000000
# max                4.000000                   3144.000000

# %% [markdown]
# # 2. 统计IP重复使用次数
# 因为源数据已经有序,因此没有额外做排序处理

# %%
ip_count = df.iloc[:, [0, 2]]
ip_count.head(10)
ip_count.dtypes
# Out:
# _id                             object
# uniqueTrainingPersonIdsCount     int64
# dtype: object

# %% [markdown]
# # 统计IP地址重复使用次数
#
# **直方图形式**

# %%
# 要求图表中只有 1 行 1 列子图，并且设置图表的大小为 10 * 10
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10, 10))

# 绘制柱状图
num_elements = 40
ax.bar(ip_count.head(num_elements)._id, ip_count.head(num_elements).uniqueTrainingPersonIdsCount)

# 设置标题
ax.set_xlabel('IP address')
ax.set_ylabel('Count')

# 设置x轴标签倾斜45度
plt.xticks(rotation=45)

# 设置 y 轴刻度精度
plt.yticks(np.arange(0, 3000, 100))

plt.savefig('../imgs/ip_student.png', dpi=300, bbox_inches='tight', pad_inches=1)
plt.show()
